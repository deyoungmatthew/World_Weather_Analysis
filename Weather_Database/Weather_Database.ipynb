# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
from datetime import datetime

# %%
# Creat set of 2,000 random lats and lngs
lats = np.random.uniform(-90,90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Creating a lit out of lats and lngs from the zip
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
import requests

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list for city weather data
city_data = []

# print beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create Counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
  # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
           
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 10 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 16 | torbay
# Processing Record 12 of Set 16 | bredasdorp
# Processing Record 13 of Set 16 | sao francisco de assis
# Processing Record 14 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 16 | marquette
# Processing Record 16 of Set 16 | saint anthony
# Processing Record 17 of Set 16 | carnarvon
# Processing Record 18 of Set 16 | kaitangata
# Processing Record 19 of Set 16 | saskylakh
# Processing Record 20 of Set 16 | atar
# Processing Record 21 of Set 16 | sanda
# Processing Record 22 of Set 16 | butaritari
# Processing Record 23 of Set 16 | ancud
# Processing Record 24 of Set 16 | mahebourg
# Processing Record 25 of Set 16 | nikolskoye
# Processing Record 26 of Set 16 | portland
# Processing Record 27 of Set 16 | yellowknife
# Processing Record 28 of Set 16 | vila franca do campo
# Processing Record 29 of Set 16 | cape town
# Processing Record 30 of Set 16 | jega
# Processing Record 31 of Set 16 | suamico
# Processing Record 32 of Set 16 | tsumeb
# Processing Record 33 of Set 16 | busselton
# Processing Record 34 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 16 | cayenne
# Processing Record 36 of Set 16 | bodden town
# Processing Record 37 of Set 16 | chuy
# Processing Record 38 of Set 16 | konstantinovka
# Processing Record 39 of Set 16 | nichinan
# Processing Record 40 of Set 16 | chokurdakh
# Processing Record 41 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 16 | elbistan
# Processing Record 43 of Set 16 | tchibanga
# Processing Record 44 of Set 16 | bluff
# Processing Record 45 of Set 16 | qaanaaq
# Processing Record 46 of Set 16 | maniitsoq
# Processing Record 47 of Set 16 | jamestown
# Processing Record 48 of Set 16 | kapaa
# Processing Record 49 of Set 16 | lebu
# Processing Record 50 of Set 16 | hermanus
# Processing Record 51 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 52 of Set 16 | ales
# Processing Record 53 of Set 16 | fiumicino
# Processing Record 54 of Set 16 | albany
# Processing Record 55 of Set 16 | rairangpur
# Processing Record 56 of Set 16 | norman wells
# Processing Record 57 of Set 16 | solnechnyy
# Processing Record 58 of Set 16 | hobart
# Processing Record 59 of Set 16 | mogadishu
# Processing Record 1 of Set 17 | atuona
# Processing Record 2 of Set 17 | isiolo
# Processing Record 3 of Set 17 | roald
# Processing Record 4 of Set 17 | anadyr
# Processing Record 5 of Set 17 | isangel
# Processing Record 6 of Set 17 | punta arenas
# Processing Record 7 of Set 17 | rikitea
# Processing Record 8 of Set 17 | bubaque
# Processing Record 9 of Set 17 | jonesboro
# Processing Record 10 of Set 17 | ojinaga
# Processing Record 11 of Set 17 | pringsewu
# Processing Record 12 of Set 17 | castro
# Processing Record 13 of Set 17 | camacha
# Processing Record 14 of Set 17 | provideniya
# Processing Record 15 of Set 17 | najran
# Processing Record 16 of Set 17 | byron bay
# Processing Record 17 of Set 17 | fortuna
# Processing Record 18 of Set 17 | wasilla
# Processing Record 19 of Set 17 | sao felix do xingu
# Processing Record 20 of Set 17 | yinchuan
# Processing Record 21 of Set 17 | mataura
# Processing Record 22 of Set 17 | joshimath
# Processing Record 23 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 17 | new norfolk
# Processing Record 25 of Set 17 | guerrero negro
# Processing Record 26 of Set 17 | margate
# Processing Record 27 of Set 17 | shingu
# Processing Record 28 of Set 17 | saldanha
# Processing Record 29 of Set 17 | seymchan
# Processing Record 30 of Set 17 | ushuaia
# Processing Record 31 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 17 | tiksi
# Processing Record 33 of Set 17 | batagay-alyta
# Processing Record 34 of Set 17 | namibe
# Processing Record 35 of Set 17 | the pas
# Processing Record 36 of Set 17 | vaini
# Processing Record 37 of Set 17 | kamen-na-obi
# Processing Record 38 of Set 17 | pisco
# Processing Record 39 of Set 17 | manaure
# Processing Record 40 of Set 17 | antalaha
# Processing Record 41 of Set 17 | cockburn town
# Processing Record 42 of Set 17 | porto novo
# Processing Record 43 of Set 17 | nuevitas
# Processing Record 44 of Set 17 | saint-philippe
# Processing Record 45 of Set 17 | avarua
# Processing Record 46 of Set 17 | mar del plata
# Processing Record 47 of Set 17 | arraial do cabo
# Processing Record 48 of Set 17 | erzin
# Processing Record 49 of Set 17 | salinas
# Processing Record 50 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 18 | bethel
# Processing Record 2 of Set 18 | sangar
# Processing Record 3 of Set 18 | namatanai
# Processing Record 4 of Set 18 | lethem
# Processing Record 5 of Set 18 | lukovetskiy
# Processing Record 6 of Set 18 | barrow
# Processing Record 7 of Set 18 | pemangkat
# Processing Record 8 of Set 18 | constitucion
# Processing Record 9 of Set 18 | trujillo
# Processing Record 10 of Set 18 | thompson
# Processing Record 11 of Set 18 | hilo
# Processing Record 12 of Set 18 | nalut
# Processing Record 13 of Set 18 | jambol
# City not found. Skipping...
# Processing Record 14 of Set 18 | port alfred
# Processing Record 15 of Set 18 | cadillac
# Processing Record 16 of Set 18 | bengkulu
# Processing Record 17 of Set 18 | nongstoin
# Processing Record 18 of Set 18 | puerto escondido
# Processing Record 19 of Set 18 | umm kaddadah
# Processing Record 20 of Set 18 | rathcoole
# Processing Record 21 of Set 18 | taltal
# Processing Record 22 of Set 18 | hasaki
# Processing Record 23 of Set 18 | itoman
# Processing Record 24 of Set 18 | carahue
# Processing Record 25 of Set 18 | east london
# Processing Record 26 of Set 18 | puerto ayora
# Processing Record 27 of Set 18 | alofi
# Processing Record 28 of Set 18 | san jose
# Processing Record 29 of Set 18 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 18 | wajir
# Processing Record 31 of Set 18 | ribeira grande
# Processing Record 32 of Set 18 | chauk
# Processing Record 33 of Set 18 | poum
# Processing Record 34 of Set 18 | bokoro
# Processing Record 35 of Set 18 | sao jose da coroa grande
# Processing Record 36 of Set 18 | necochea
# Processing Record 37 of Set 18 | jerantut
# Processing Record 38 of Set 18 | padang
# Processing Record 39 of Set 18 | myrtle beach
# Processing Record 40 of Set 18 | nongpoh
# Processing Record 41 of Set 18 | luena
# Processing Record 42 of Set 18 | okhotsk
# Processing Record 43 of Set 18 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 18 | manggar
# Processing Record 45 of Set 18 | westport
# Processing Record 46 of Set 18 | aitape
# Processing Record 47 of Set 18 | lima
# Processing Record 48 of Set 18 | san vicente
# Processing Record 49 of Set 18 | narsaq
# Processing Record 50 of Set 18 | cabo san lucas
# Processing Record 1 of Set 19 | esperance
# Processing Record 2 of Set 19 | tuktoyaktuk
# Processing Record 3 of Set 19 | lasa
# Processing Record 4 of Set 19 | asau
# Processing Record 5 of Set 19 | laem sing
# Processing Record 6 of Set 19 | georgetown
# Processing Record 7 of Set 19 | muramatsu
# Processing Record 8 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 19 | geraldton
# Processing Record 10 of Set 19 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 19 | kargasok
# Processing Record 12 of Set 19 | srednekolymsk
# Processing Record 13 of Set 19 | ilulissat
# Processing Record 14 of Set 19 | nanortalik
# Processing Record 15 of Set 19 | leona vicario
# Processing Record 16 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 19 | quatre cocos
# Processing Record 18 of Set 19 | khatanga
# Processing Record 19 of Set 19 | davila
# Processing Record 20 of Set 19 | ussel
# Processing Record 21 of Set 19 | klaksvik
# Processing Record 22 of Set 19 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 19 | malgrat de mar
# Processing Record 24 of Set 19 | borogontsy
# Processing Record 25 of Set 19 | paducah
# Processing Record 26 of Set 19 | naze
# Processing Record 27 of Set 19 | ishinomaki
# Processing Record 28 of Set 19 | visegrad
# Processing Record 29 of Set 19 | kodiak
# Processing Record 30 of Set 19 | komsomolskiy
# Processing Record 31 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 19 | moen
# Processing Record 33 of Set 19 | waipawa
# Processing Record 34 of Set 19 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 19 | khalkhal
# Processing Record 37 of Set 19 | coihaique
# Processing Record 38 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 19 | sola
# Processing Record 40 of Set 19 | birjand
# Processing Record 41 of Set 19 | kara
# Processing Record 42 of Set 19 | gorontalo
# Processing Record 43 of Set 19 | ketchikan
# Processing Record 44 of Set 19 | havre-saint-pierre
# Processing Record 45 of Set 19 | oussouye
# Processing Record 46 of Set 19 | airai
# Processing Record 47 of Set 19 | kemi
# Processing Record 48 of Set 19 | waingapu
# Processing Record 49 of Set 19 | brae
# Processing Record 50 of Set 19 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 20 | taungdwingyi
# Processing Record 2 of Set 20 | thanh hoa
# Processing Record 3 of Set 20 | linxia
# Processing Record 4 of Set 20 | souillac
# Processing Record 5 of Set 20 | cap malheureux
# Processing Record 6 of Set 20 | madison
# Processing Record 7 of Set 20 | hithadhoo
# Processing Record 8 of Set 20 | ostersund
# Processing Record 9 of Set 20 | vostok
# Processing Record 10 of Set 20 | takoradi
# Processing Record 11 of Set 20 | port elizabeth
# Processing Record 12 of Set 20 | manakara
# Processing Record 13 of Set 20 | lufilufi
# Processing Record 14 of Set 20 | dikson
# Processing Record 15 of Set 20 | yozgat
# Processing Record 16 of Set 20 | vanavara
# Processing Record 17 of Set 20 | kruisfontein
# Processing Record 18 of Set 20 | cherskiy
# Processing Record 19 of Set 20 | miquelon
# Processing Record 20 of Set 20 | sisimiut
# Processing Record 21 of Set 20 | lorengau
# Processing Record 22 of Set 20 | salalah
# Processing Record 23 of Set 20 | kamaishi
# Processing Record 24 of Set 20 | tripoli
# Processing Record 25 of Set 20 | aklavik
# Processing Record 26 of Set 20 | abalak
# Processing Record 27 of Set 20 | michalovce
# Processing Record 28 of Set 20 | atasu
# Processing Record 29 of Set 20 | nemuro
# Processing Record 30 of Set 20 | thinadhoo
# Processing Record 31 of Set 20 | svetlyy
# Processing Record 32 of Set 20 | manga
# Processing Record 33 of Set 20 | noumea
# Processing Record 34 of Set 20 | comodoro rivadavia
# Processing Record 35 of Set 20 | san cristobal
# Processing Record 36 of Set 20 | longyearbyen
# Processing Record 37 of Set 20 | clyde river
# Processing Record 38 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 20 | sungaipenuh
# Processing Record 40 of Set 20 | fandriana
# Processing Record 41 of Set 20 | ponta do sol
# Processing Record 42 of Set 20 | tazovskiy
# Processing Record 43 of Set 20 | san patricio
# Processing Record 44 of Set 20 | chilliwack
# Processing Record 45 of Set 20 | ondjiva
# Processing Record 46 of Set 20 | barcelona
# Processing Record 47 of Set 20 | picton
# Processing Record 48 of Set 20 | muromtsevo
# Processing Record 49 of Set 20 | darhan
# Processing Record 50 of Set 20 | kjopsvik
# Processing Record 1 of Set 21 | aljezur
# Processing Record 2 of Set 21 | rumonge
# Processing Record 3 of Set 21 | te anau
# Processing Record 4 of Set 21 | piranshahr
# Processing Record 5 of Set 21 | pevek
# Processing Record 6 of Set 21 | lompoc
# Processing Record 7 of Set 21 | upernavik
# Processing Record 8 of Set 21 | broken hill
# Processing Record 9 of Set 21 | sindor
# Processing Record 10 of Set 21 | cap-haitien
# Processing Record 11 of Set 21 | bathsheba
# Processing Record 12 of Set 21 | saint george
# Processing Record 13 of Set 21 | taksimo
# Processing Record 14 of Set 21 | puerto el triunfo
# Processing Record 15 of Set 21 | lypova dolyna
# Processing Record 16 of Set 21 | hay river
# Processing Record 17 of Set 21 | gwadar
# Processing Record 18 of Set 21 | faanui
# Processing Record 19 of Set 21 | coahuayana
# Processing Record 20 of Set 21 | valparaiso
# Processing Record 21 of Set 21 | changde
# Processing Record 22 of Set 21 | eureka
# Processing Record 23 of Set 21 | kastamonu
# Processing Record 24 of Set 21 | greenville
# Processing Record 25 of Set 21 | talnakh
# Processing Record 26 of Set 21 | temanggung
# Processing Record 27 of Set 21 | catia la mar
# Processing Record 28 of Set 21 | zharkent
# Processing Record 29 of Set 21 | giddarbaha
# Processing Record 30 of Set 21 | bayir
# Processing Record 31 of Set 21 | palmer
# Processing Record 32 of Set 21 | nome
# Processing Record 33 of Set 21 | ribas do rio pardo
# Processing Record 34 of Set 21 | tirano
# Processing Record 35 of Set 21 | lufkin
# Processing Record 36 of Set 21 | tuatapere
# Processing Record 37 of Set 21 | morant bay
# Processing Record 38 of Set 21 | atambua
# Processing Record 39 of Set 21 | east wenatchee bench
# Processing Record 40 of Set 21 | bud
# Processing Record 41 of Set 21 | honiara
# Processing Record 42 of Set 21 | homer
# Processing Record 43 of Set 21 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record 44 of Set 21 | coquimbo
# Processing Record 45 of Set 21 | sao miguel do araguaia
# Processing Record 46 of Set 21 | beringovskiy
# Processing Record 47 of Set 21 | chapleau
# Processing Record 48 of Set 21 | anito
# Processing Record 49 of Set 21 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 21 | broome
# Processing Record 1 of Set 22 | port lincoln
# Processing Record 2 of Set 22 | ballina
# Processing Record 3 of Set 22 | mandapam
# Processing Record 4 of Set 22 | monrovia
# Processing Record 5 of Set 22 | norsup
# Processing Record 6 of Set 22 | sitka
# Processing Record 7 of Set 22 | bambous virieux
# Processing Record 8 of Set 22 | labuhan
# Processing Record 9 of Set 22 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 22 | tshikapa
# Processing Record 11 of Set 22 | half moon bay
# Processing Record 12 of Set 22 | pacific grove
# Processing Record 13 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 22 | syracuse
# Processing Record 15 of Set 22 | porto belo
# Processing Record 16 of Set 22 | sinnamary
# Processing Record 17 of Set 22 | pokrovka
# Processing Record 18 of Set 22 | reading
# Processing Record 19 of Set 22 | furano
# Processing Record 20 of Set 22 | shizukuishi
# Processing Record 21 of Set 22 | tchollire
# Processing Record 22 of Set 22 | tangshan
# Processing Record 23 of Set 22 | taoudenni
# Processing Record 24 of Set 22 | juneau
# Processing Record 25 of Set 22 | bam
# Processing Record 26 of Set 22 | saugus
# Processing Record 27 of Set 22 | trincomalee
# Processing Record 28 of Set 22 | gat
# Processing Record 29 of Set 22 | meulaboh
# Processing Record 30 of Set 22 | tadine
# Processing Record 31 of Set 22 | bandarbeyla
# Processing Record 32 of Set 22 | codrington
# Processing Record 33 of Set 22 | laguna
# Processing Record 34 of Set 22 | rawson
# Processing Record 35 of Set 22 | never
# Processing Record 36 of Set 22 | kayanza
# Processing Record 37 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 22 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 22 | san quintin
# Processing Record 40 of Set 22 | luangwa
# Processing Record 41 of Set 22 | rosario
# Processing Record 42 of Set 22 | zeya
# Processing Record 43 of Set 22 | dnestrovsc
# Processing Record 44 of Set 22 | la rioja
# Processing Record 45 of Set 22 | adrar
# Processing Record 46 of Set 22 | wadi maliz
# Processing Record 47 of Set 22 | omboue
# Processing Record 48 of Set 22 | kahului
# Processing Record 49 of Set 22 | los llanos de aridane
# Processing Record 50 of Set 22 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 23 | karcsa
# Processing Record 2 of Set 23 | dalianwan
# Processing Record 3 of Set 23 | ust-uda
# Processing Record 4 of Set 23 | ovsyanka
# Processing Record 5 of Set 23 | mabaruma
# Processing Record 6 of Set 23 | jomalig
# City not found. Skipping...
# Processing Record 7 of Set 23 | okitipupa
# Processing Record 8 of Set 23 | kovernino
# Processing Record 9 of Set 23 | maun
# Processing Record 10 of Set 23 | arman
# Processing Record 11 of Set 23 | kasongo-lunda
# Processing Record 12 of Set 23 | gibara
# Processing Record 13 of Set 23 | bilibino
# Processing Record 14 of Set 23 | srandakan
# Processing Record 15 of Set 23 | alihe
# Processing Record 16 of Set 23 | ambilobe
# Processing Record 17 of Set 23 | touros
# Processing Record 18 of Set 23 | mersing
# Processing Record 19 of Set 23 | loreto
# Processing Record 20 of Set 23 | vestmannaeyjar
# Processing Record 21 of Set 23 | ukiah
# Processing Record 22 of Set 23 | tamboril
# Processing Record 23 of Set 23 | tornio
# Processing Record 24 of Set 23 | general roca
# Processing Record 25 of Set 23 | port blair
# Processing Record 26 of Set 23 | burns lake
# Processing Record 27 of Set 23 | yerbogachen
# Processing Record 28 of Set 23 | kollam
# Processing Record 29 of Set 23 | paragominas
# Processing Record 30 of Set 23 | kangaatsiaq
# Processing Record 31 of Set 23 | moose factory
# Processing Record 32 of Set 23 | matamoros
# Processing Record 33 of Set 23 | antibes
# Processing Record 34 of Set 23 | kamenka
# Processing Record 35 of Set 23 | darab
# Processing Record 36 of Set 23 | cobija
# Processing Record 37 of Set 23 | ipora
# Processing Record 38 of Set 23 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 23 | warwick
# Processing Record 40 of Set 23 | rudnyy
# Processing Record 41 of Set 23 | acarau
# Processing Record 42 of Set 23 | saint-georges
# Processing Record 43 of Set 23 | perth
# Processing Record 44 of Set 23 | qinhuangdao
# Processing Record 45 of Set 23 | sept-iles
# Processing Record 46 of Set 23 | teacapan
# Processing Record 47 of Set 23 | ati
# Processing Record 48 of Set 23 | la asuncion
# Processing Record 49 of Set 23 | leshukonskoye
# Processing Record 50 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 24 | urumqi
# Processing Record 2 of Set 24 | melfort
# Processing Record 3 of Set 24 | serenje
# Processing Record 4 of Set 24 | zhezkazgan
# Processing Record 5 of Set 24 | fort frances
# Processing Record 6 of Set 24 | sawtell
# Processing Record 7 of Set 24 | camden
# Processing Record 8 of Set 24 | nadym
# Processing Record 9 of Set 24 | ajaccio
# Processing Record 10 of Set 24 | severo-kurilsk
# Processing Record 11 of Set 24 | melilla
# Processing Record 12 of Set 24 | maceio
# Processing Record 13 of Set 24 | kutum
# Processing Record 14 of Set 24 | morondava
# Processing Record 15 of Set 24 | boden
# Processing Record 16 of Set 24 | conde
# Processing Record 17 of Set 24 | kinablangan
# Processing Record 18 of Set 24 | ariquemes
# Processing Record 19 of Set 24 | hope
# Processing Record 20 of Set 24 | luwingu
# Processing Record 21 of Set 24 | alta floresta
# Processing Record 22 of Set 24 | aksu
# Processing Record 23 of Set 24 | belaya gora
# Processing Record 24 of Set 24 | viedma
# Processing Record 25 of Set 24 | acapulco
# Processing Record 26 of Set 24 | kisangani
# Processing Record 27 of Set 24 | seoul
# Processing Record 28 of Set 24 | lagoa
# Processing Record 29 of Set 24 | victor harbor
# Processing Record 30 of Set 24 | la ronge
# Processing Record 31 of Set 24 | walvis bay
# Processing Record 32 of Set 24 | edson
# Processing Record 33 of Set 24 | dillon
# Processing Record 34 of Set 24 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 24 | huambo
# Processing Record 36 of Set 24 | lavrentiya
# Processing Record 37 of Set 24 | hamilton
# Processing Record 38 of Set 24 | tasiilaq
# Processing Record 39 of Set 24 | batagay
# Processing Record 40 of Set 24 | ingham
# Processing Record 41 of Set 24 | hirara
# Processing Record 42 of Set 24 | pajapan
# Processing Record 43 of Set 24 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 24 | mackay
# Processing Record 45 of Set 24 | campo grande
# Processing Record 46 of Set 24 | zunyi
# Processing Record 47 of Set 24 | avera
# Processing Record 48 of Set 24 | port augusta
# Processing Record 49 of Set 24 | dingle
# Processing Record 50 of Set 24 | yelan-koleno
# Processing Record 1 of Set 25 | birnin kebbi
# Processing Record 2 of Set 25 | dunedin
# Processing Record 3 of Set 25 | boulsa
# Processing Record 4 of Set 25 | sur
# Processing Record 5 of Set 25 | katsuura
# Processing Record 6 of Set 25 | san lawrenz
# Processing Record 7 of Set 25 | do gonbadan
# Processing Record 8 of Set 25 | marzuq
# Processing Record 9 of Set 25 | luxor
# Processing Record 10 of Set 25 | qasigiannguit
# Processing Record 11 of Set 25 | mingguang
# Processing Record 12 of Set 25 | helena
# Processing Record 13 of Set 25 | cairns
# Processing Record 14 of Set 25 | milkovo
# Processing Record 15 of Set 25 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 25 | kokstad
# Processing Record 17 of Set 25 | omsukchan
# Processing Record 18 of Set 25 | gushikawa
# Processing Record 19 of Set 25 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 25 | meadow lake
# Processing Record 21 of Set 25 | bom jardim
# Processing Record 22 of Set 25 | port hardy
# Processing Record 23 of Set 25 | novikovo
# Processing Record 24 of Set 25 | shchelyayur
# City not found. Skipping...
# Processing Record 25 of Set 25 | sturgeon bay
# Processing Record 26 of Set 25 | altay
# Processing Record 27 of Set 25 | abilene
# Processing Record 28 of Set 25 | paamiut
# Processing Record 29 of Set 25 | nhulunbuy
# Processing Record 30 of Set 25 | zlitan
# Processing Record 31 of Set 25 | baza
# Processing Record 32 of Set 25 | sao luiz gonzaga
# Processing Record 33 of Set 25 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 25 | nakusp
# Processing Record 35 of Set 25 | zyryanka
# Processing Record 36 of Set 25 | teruel
# Processing Record 37 of Set 25 | college
# Processing Record 38 of Set 25 | avesta
# Processing Record 39 of Set 25 | balcauti
# Processing Record 40 of Set 25 | pakenham
# Processing Record 41 of Set 25 | akdagmadeni
# Processing Record 42 of Set 25 | hovd
# Processing Record 43 of Set 25 | katherine
# Processing Record 44 of Set 25 | qeshm
# Processing Record 45 of Set 25 | gerede
# Processing Record 46 of Set 25 | shitanjing
# Processing Record 47 of Set 25 | belyy yar
# Processing Record 48 of Set 25 | bababe
# City not found. Skipping...
# Processing Record 49 of Set 25 | tulskiy
# Processing Record 50 of Set 25 | locri
# Processing Record 1 of Set 26 | udachnyy
# Processing Record 2 of Set 26 | port macquarie
# Processing Record 3 of Set 26 | alegrete
# Processing Record 4 of Set 26 | muriti
# Processing Record 5 of Set 26 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 26 | sorland
# Processing Record 7 of Set 26 | pangnirtung
# Processing Record 8 of Set 26 | lata
# Processing Record 9 of Set 26 | ola
# Processing Record 10 of Set 26 | okulovka
# Processing Record 11 of Set 26 | sambava
# Processing Record 12 of Set 26 | nizhneudinsk
# Processing Record 13 of Set 26 | zonguldak
# Processing Record 14 of Set 26 | bonavista
# Processing Record 15 of Set 26 | domoni
# Processing Record 16 of Set 26 | atherton
# Processing Record 17 of Set 26 | labytnangi
# Processing Record 18 of Set 26 | iquitos
# Processing Record 19 of Set 26 | gazli
# Processing Record 20 of Set 26 | maloshuyka
# City not found. Skipping...
# Processing Record 21 of Set 26 | talhar
# Processing Record 22 of Set 26 | tahe
# Processing Record 23 of Set 26 | paszto
# Processing Record 24 of Set 26 | chengkung
# City not found. Skipping...
# Processing Record 25 of Set 26 | viransehir
# Processing Record 26 of Set 26 | shubarshi
# Processing Record 27 of Set 26 | kodinsk
# Processing Record 28 of Set 26 | troitskoye
# Processing Record 29 of Set 26 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 26 | venado tuerto
# Processing Record 31 of Set 26 | eucaliptus
# Processing Record 32 of Set 26 | victoria
# Processing Record 33 of Set 26 | carutapera
# Processing Record 34 of Set 26 | inhambane
# Processing Record 35 of Set 26 | leningradskiy
# Processing Record 36 of Set 26 | ossora
# Processing Record 37 of Set 26 | strezhevoy
# Processing Record 38 of Set 26 | nagapattinam
# Processing Record 39 of Set 26 | mazatlan
# Processing Record 40 of Set 26 | fairbanks
# Processing Record 41 of Set 26 | sao joao da barra
# Processing Record 42 of Set 26 | saint-pierre
# Processing Record 43 of Set 26 | nioro
# Processing Record 44 of Set 26 | biloela
# Processing Record 45 of Set 26 | shubarkuduk
# Processing Record 46 of Set 26 | sosnovo-ozerskoye
# Processing Record 47 of Set 26 | shimoda
# Processing Record 48 of Set 26 | elk river
# Processing Record 49 of Set 26 | mayo
# Processing Record 50 of Set 26 | baglung
# Processing Record 1 of Set 27 | beni
# Processing Record 2 of Set 27 | iqaluit
# Processing Record 3 of Set 27 | la romana
# Processing Record 4 of Set 27 | mwene-ditu
# Processing Record 5 of Set 27 | kardla
# Processing Record 6 of Set 27 | mehamn
# Processing Record 7 of Set 27 | gisborne
# Processing Record 8 of Set 27 | tabuk
# Processing Record 9 of Set 27 | tabas
# Processing Record 10 of Set 27 | erenhot
# Processing Record 11 of Set 27 | mahanje
# Processing Record 12 of Set 27 | kendari
# Processing Record 13 of Set 27 | siuna
# Processing Record 14 of Set 27 | svetlaya
# Processing Record 15 of Set 27 | sijunjung
# Processing Record 16 of Set 27 | caravelas
# Processing Record 17 of Set 27 | phan thiet
# Processing Record 18 of Set 27 | veraval
# Processing Record 19 of Set 27 | sabha
# Processing Record 20 of Set 27 | mataram
# Processing Record 21 of Set 27 | araouane
# Processing Record 22 of Set 27 | leh
# Processing Record 23 of Set 27 | cuencame
# Processing Record 24 of Set 27 | fukue
# Processing Record 25 of Set 27 | tabou
# Processing Record 26 of Set 27 | baley
# Processing Record 27 of Set 27 | mount gambier
# Processing Record 28 of Set 27 | hornepayne
# Processing Record 29 of Set 27 | khash
# Processing Record 30 of Set 27 | port hedland
# Processing Record 31 of Set 27 | derzhavinsk
# Processing Record 32 of Set 27 | tommot
# Processing Record 33 of Set 27 | dreznica
# Processing Record 34 of Set 27 | orlik
# Processing Record 35 of Set 27 | prince rupert
# Processing Record 36 of Set 27 | sigli
# Processing Record 37 of Set 27 | litovko
# Processing Record 38 of Set 27 | muli
# Processing Record 39 of Set 27 | wynyard
# Processing Record 40 of Set 27 | yarmouth
# Processing Record 41 of Set 27 | corinto
# Processing Record 42 of Set 27 | topchikha
# Processing Record 43 of Set 27 | libertador general san martin
# Processing Record 44 of Set 27 | yamada
# Processing Record 45 of Set 27 | grootfontein
# Processing Record 46 of Set 27 | bocas del toro
# Processing Record 47 of Set 27 | fort nelson
# Processing Record 48 of Set 27 | hami
# Processing Record 49 of Set 27 | abnub
# Processing Record 50 of Set 27 | maamba
# Processing Record 1 of Set 28 | kununurra
# Processing Record 2 of Set 28 | hualmay
# Processing Record 3 of Set 28 | neyvo-shaytanskiy
# Processing Record 4 of Set 28 | yaan
# Processing Record 5 of Set 28 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 28 | igarka
# Processing Record 7 of Set 28 | ucluelet
# Processing Record 8 of Set 28 | champerico
# Processing Record 9 of Set 28 | vasai
# Processing Record 10 of Set 28 | muros
# Processing Record 11 of Set 28 | payakumbuh
# Processing Record 12 of Set 28 | zhigansk
# Processing Record 13 of Set 28 | reno
# Processing Record 14 of Set 28 | saint-louis
# Processing Record 15 of Set 28 | gurskoye
# City not found. Skipping...
# Processing Record 16 of Set 28 | hervey bay
# Processing Record 17 of Set 28 | demba
# Processing Record 18 of Set 28 | shestakovo
# Processing Record 19 of Set 28 | governador dix-sept rosado
# Processing Record 20 of Set 28 | matay
# Processing Record 21 of Set 28 | shieli
# Processing Record 22 of Set 28 | mount isa
# Processing Record 23 of Set 28 | lastoursville
# Processing Record 24 of Set 28 | juquia
# Processing Record 25 of Set 28 | busdi
# Processing Record 26 of Set 28 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 28 | nabire
# Processing Record 28 of Set 28 | borovskiy
# Processing Record 29 of Set 28 | port-gentil
# Processing Record 30 of Set 28 | bongandanga
# Processing Record 31 of Set 28 | kuching
# Processing Record 32 of Set 28 | ferkessedougou
# Processing Record 33 of Set 28 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 28 | akoupe
# Processing Record 35 of Set 28 | hambantota
# Processing Record 36 of Set 28 | nishihara
# Processing Record 37 of Set 28 | pokrovsk
# Processing Record 38 of Set 28 | edd
# Processing Record 39 of Set 28 | kaeo
# Processing Record 40 of Set 28 | klichka
# Processing Record 41 of Set 28 | standerton
# Processing Record 42 of Set 28 | rocha
# Processing Record 43 of Set 28 | aksarka
# Processing Record 44 of Set 28 | kochki
# Processing Record 45 of Set 28 | mendahara
# City not found. Skipping...
# Processing Record 46 of Set 28 | pandan
# Processing Record 47 of Set 28 | cacu
# Processing Record 48 of Set 28 | cidreira
# Processing Record 49 of Set 28 | puerto lumbreras
# Processing Record 50 of Set 28 | maldonado
# Processing Record 1 of Set 29 | cubuk
# Processing Record 2 of Set 29 | buala
# Processing Record 3 of Set 29 | abiy adi
# City not found. Skipping...
# Processing Record 4 of Set 29 | wageningen
# Processing Record 5 of Set 29 | ashland
# Processing Record 6 of Set 29 | hofn
# Processing Record 7 of Set 29 | marsh harbour
# Processing Record 8 of Set 29 | revelstoke
# Processing Record 9 of Set 29 | yialos
# City not found. Skipping...
# Processing Record 10 of Set 29 | umm lajj
# Processing Record 11 of Set 29 | la paz
# Processing Record 12 of Set 29 | huazolotitlan
# City not found. Skipping...
# Processing Record 13 of Set 29 | katangli
# Processing Record 14 of Set 29 | quballat
# Processing Record 15 of Set 29 | douala
# Processing Record 16 of Set 29 | isiro
# Processing Record 17 of Set 29 | mednogorsk
# Processing Record 18 of Set 29 | sibolga
# Processing Record 19 of Set 29 | saint-augustin
# Processing Record 20 of Set 29 | lodja
# Processing Record 21 of Set 29 | taburao
# City not found. Skipping...
# Processing Record 22 of Set 29 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 29 | mosquera
# Processing Record 24 of Set 29 | dubbo
# Processing Record 25 of Set 29 | bowen
# Processing Record 26 of Set 29 | saint-michel-des-saints
# Processing Record 27 of Set 29 | kudahuvadhoo
# Processing Record 28 of Set 29 | mandalgovi
# Processing Record 29 of Set 29 | rio gallegos
# Processing Record 30 of Set 29 | ixtapa
# Processing Record 31 of Set 29 | tambura
# Processing Record 32 of Set 29 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 29 | wolmaranstad
# City not found. Skipping...
# Processing Record 34 of Set 29 | halvad
# Processing Record 35 of Set 29 | tual
# Processing Record 36 of Set 29 | ginir
# Processing Record 37 of Set 29 | itarema
# Processing Record 38 of Set 29 | ulladulla
# Processing Record 39 of Set 29 | kembolcha
# Processing Record 40 of Set 29 | usogorsk
# Processing Record 41 of Set 29 | ibra
# Processing Record 42 of Set 29 | vao
# Processing Record 43 of Set 29 | daru
# Processing Record 44 of Set 29 | uvalde
# Processing Record 45 of Set 29 | angoram
# Processing Record 46 of Set 29 | kavaratti
# Processing Record 47 of Set 29 | atikokan
# Processing Record 48 of Set 29 | talcahuano
# Processing Record 49 of Set 29 | faya
# Processing Record 50 of Set 29 | huanren
# Processing Record 1 of Set 30 | san joaquin
# Processing Record 2 of Set 30 | poienari
# Processing Record 3 of Set 30 | palmares do sul
# Processing Record 4 of Set 30 | vega de alatorre
# Processing Record 5 of Set 30 | makakilo city
# Processing Record 6 of Set 30 | istok
# Processing Record 7 of Set 30 | goderich
# Processing Record 8 of Set 30 | punta alta
# Processing Record 9 of Set 30 | velyka bahachka
# Processing Record 10 of Set 30 | sao filipe
# Processing Record 11 of Set 30 | bezhanitsy
# Processing Record 12 of Set 30 | tautira
# Processing Record 13 of Set 30 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 30 | ambovombe
# Processing Record 15 of Set 30 | waddan
# Processing Record 16 of Set 30 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 30 | kushiro
# Processing Record 18 of Set 30 | santa marinella
# Processing Record 19 of Set 30 | rognan
# Processing Record 20 of Set 30 | beira
# Processing Record 21 of Set 30 | camana
# Processing Record 22 of Set 30 | evensk
# Processing Record 23 of Set 30 | havelock
# Processing Record 24 of Set 30 | jalpan
# Processing Record 25 of Set 30 | khadzhalmakhi
# Processing Record 26 of Set 30 | san policarpo
# Processing Record 27 of Set 30 | turayf
# Processing Record 28 of Set 30 | miranda
# Processing Record 29 of Set 30 | frauenfeld
# Processing Record 30 of Set 30 | kandrian
# Processing Record 31 of Set 30 | stuhr
# Processing Record 32 of Set 30 | dakar
# Processing Record 33 of Set 30 | keti bandar
# Processing Record 34 of Set 30 | saint-marc-des-carrieres
# Processing Record 35 of Set 30 | fortuna foothills
# Processing Record 36 of Set 30 | yirol
# City not found. Skipping...
# Processing Record 37 of Set 30 | zorritos
# Processing Record 38 of Set 30 | tucuman
# Processing Record 39 of Set 30 | egvekinot
# Processing Record 40 of Set 30 | lat yao
# Processing Record 41 of Set 30 | esmeraldas
# Processing Record 42 of Set 30 | luang prabang
# Processing Record 43 of Set 30 | taga
# Processing Record 44 of Set 30 | talaya
# Processing Record 45 of Set 30 | lashio
# Processing Record 46 of Set 30 | alyangula
# Processing Record 47 of Set 30 | pindobacu
# Processing Record 48 of Set 30 | hobyo
# Processing Record 49 of Set 30 | rafaela
# Processing Record 50 of Set 30 | taburbah
# City not found. Skipping...
# Processing Record 1 of Set 31 | nouadhibou
# Processing Record 2 of Set 31 | bridge of earn
# Processing Record 3 of Set 31 | damoh
# Processing Record 4 of Set 31 | itapuranga
# Processing Record 5 of Set 31 | mwinilunga
# Processing Record 6 of Set 31 | linjiang
# Processing Record 7 of Set 31 | vozhega
# Processing Record 8 of Set 31 | otta
# Processing Record 9 of Set 31 | khovu-aksy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                  Torbay  47.6666  -52.7314     37.00       100          90
# 1              Bredasdorp -34.5322   20.0403     50.00        87           0
# 2  Sao Francisco De Assis -29.5503  -55.1311     63.63        80          27
# 3               Marquette  46.5333  -87.6335     37.00        69           1
# 4           Saint Anthony  45.0205  -93.2180     53.60        46           1
# 5               Carnarvon -24.8667  113.6333     86.00        58           0
# 6              Kaitangata -46.2817  169.8464     63.00        61          37
# 7               Saskylakh  71.9167  114.0833     -6.68        91          16
# 8                    Atar  20.5169  -13.0499     78.89        18          69
# 9                   Sanda  34.8833  135.2333     62.60        94          75
#
#    Wind Speed Country      Current Description
# 0       14.97      CA  light intensity drizzle
# 1        1.14      ZA                clear sky
# 2        6.87      BR         scattered clouds
# 3        4.21      US                clear sky
# 4        4.47      US                clear sky
# 5       17.27      AU                clear sky
# 6       17.00      NZ         scattered clouds
# 7        2.68      RU               few clouds
# 8        8.39      MR            broken clouds
# 9        2.30      JP                     mist

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                    Torbay      CA  47.6666  -52.7314     37.00       100
# 1                Bredasdorp      ZA -34.5322   20.0403     50.00        87
# 2    Sao Francisco De Assis      BR -29.5503  -55.1311     63.63        80
# 3                 Marquette      US  46.5333  -87.6335     37.00        69
# 4             Saint Anthony      US  45.0205  -93.2180     53.60        46
# ..                      ...     ...      ...       ...       ...       ...
# 697              Mwinilunga      ZM -11.7358   24.4293     60.67        95
# 698                Linjiang      CN  41.8069  126.9078     49.28        23
# 699                 Vozhega      RU  60.4725   40.2213     27.46        86
# 700                    Otta      NO  61.7712    9.5353     22.03        94
# 701              Khovu-Aksy      RU  51.1333   93.6000     37.56        45
#
#      Cloudiness  Wind Speed      Current Description
# 0            90       14.97  light intensity drizzle
# 1             0        1.14                clear sky
# 2            27        6.87         scattered clouds
# 3             1        4.21                clear sky
# 4             1        4.47                clear sky
# ..          ...         ...                      ...
# 697          95        4.34          overcast clouds
# 698           1        6.06                clear sky
# 699          71        3.89            broken clouds
# 700          99        0.36          overcast clouds
# 701          85        1.54          overcast clouds
#
# [702 rows x 9 columns]

# %%
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
